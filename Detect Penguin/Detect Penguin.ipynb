# %%
import cv2
import numpy as np
#import matplotlib as plt
import matplotlib.pyplot as plt

# %%
for c in contours:
    if len(c)>90:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(image,(x,y),(x+w,y+h),(160,160,160),4)
        
    plt.imshow(image,cmap='gray')

# %%
image = cv2.imread('penguin2.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap='gray')

# %%
image1 = 255 - image
plt.imshow(image, cmap='gray')

# %%
_,thresh1 = cv2.threshold(image1,100,255,cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
contours, _ = cv2.findContours(thresh1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
for c in contours:
    if len(c)>90:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(image,(x,y),(x+w,y+h),(160,160,160),4)

plt.imshow(image,cmap='gray')
